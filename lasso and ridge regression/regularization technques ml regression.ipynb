# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(r"C:\Users\ayush\Downloads\house_data.csv")

# %%
df.head(3)
# Out:
#     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900         3       1.00         1180      5650     1.0           0
# 1  538000         3       2.25         2570      7242     2.0           0
# 2  180000         2       1.00          770     10000     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# 0    98178  47.5112 -122.257           1340        5650
# 1    98125  47.7210 -122.319           1690        7639
# 2    98028  47.7379 -122.233           2720        8062

# %%
df = df.drop('date',axis=True)

# %%
df1 = df.corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data=df1,annot=True)
plt.show()

# %%
x = df.iloc[:,1:]
x
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0             3       1.00         1180      5650     1.0           0     0
# 1             3       2.25         2570      7242     2.0           0     0
# 2             2       1.00          770     10000     1.0           0     0
# 3             4       3.00         1960      5000     1.0           0     0
# 4             3       2.00         1680      8080     1.0           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 21608         3       2.50         1530      1131     3.0           0     0
# 21609         4       2.50         2310      5813     2.0           0     0
# 21610         2       0.75         1020      1350     2.0           0     0
# 21611         3       2.50         1600      2388     2.0           0     0
# 21612         2       0.75         1020      1076     2.0           0     0
#
# ...

# %%
y = df['price']
y
# Out:
# 0        221900
# 1        538000
# 2        180000
# 3        604000
# 4        510000
#           ...
# 21608    360000
# 21609    400000
# 21610    402101
# 21611    400000
# 21612    325000
# Name: price, Length: 21613, dtype: int64

# %%
sc = StandardScaler()
sc.fit(x)
x = pd.DataFrame(sc.transform(x),columns=x.columns) 
x
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot    floors  waterfront  \
# 0     -0.398737  -1.447464    -0.979835 -0.228321 -0.915427   -0.087173
# 1     -0.398737   0.175607     0.533634 -0.189885  0.936506   -0.087173
# 2     -1.473959  -1.447464    -1.426254 -0.123298 -0.915427   -0.087173
# 3      0.676485   1.149449    -0.130550 -0.244014 -0.915427   -0.087173
# 4     -0.398737  -0.149007    -0.435422 -0.169653 -0.915427   -0.087173
# ...         ...        ...          ...       ...       ...         ...
# 21608 -0.398737   0.500221    -0.598746 -0.337424  2.788439   -0.087173
# 21609  0.676485   0.500221     0.250539 -0.224386  0.936506   -0.087173
# 21610 -1.473959  -1.772078    -1.154047 -0.332137  0.936506   -0.087173
# 21611 -0.398737   0.500221    -0.522528 -0.307076  0.936506   -0.087173
# 21612 -1.473959  -1.772078    -1.154047 -0.338752  0.936506   -0.087173
#
#            view  condition     grade  sqft_above  sqft_basement  yr_built  \
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
import numpy as np

# %% [markdown]
# # LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 70.11904448878413

# %%
print(mean_squared_error(y_test,lr.predict(x_test)))
print(mean_absolute_error(y_test,lr.predict(x_test)))
print(np.sqrt(mean_squared_error(y_test,lr.predict(x_test))))
# Out:
# 45173046132.79015
# 127493.34208656965
# 212539.51663817756

# %%
lr.coef_
# Out:
# array([-31933.32364749,  34321.16424183,  80795.07336155,   3680.01770741,
#          3781.52468658,  48657.27709491,  41105.17177702,  15960.21681122,
#        111158.08477843,  75409.77643236,  26570.28307249, -78741.50439621,
#          8200.34617126, -29547.62968731,  82577.64375415, -27402.55101001,
#         14539.78134693,  -8896.36616878])

# %%
plt.figure(figsize=(10,10))
plt.bar(x.columns,lr.coef_)
plt.title('Linear Regression')
plt.xlabel('columns')
plt.ylabel('coef')
plt.show()

# %% [markdown]
# # Lasso

# %%
la = Lasso(alpha=0.01)
la.fit(x_train,y_train)
la.score(x_test,y_test)*100
# Out:
# C:\Users\ayush\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.006e+13, tolerance: 2.259e+11
#   model = cd_fast.enet_coordinate_descent(
# 70.11904422481713

# %%
print(mean_squared_error(y_test,la.predict(x_test)))
print(mean_absolute_error(y_test,la.predict(x_test)))
print(np.sqrt(mean_squared_error(y_test,la.predict(x_test))))
# Out:
# 45173046531.84678
# 127493.34205343502
# 212539.51757695974

# %%
plt.figure(figsize=(10,10))
plt.bar(x.columns,la.coef_)
plt.title('Lasso Regression')
plt.xlabel('columns')
plt.ylabel('coef')
plt.show()

# %% [markdown]
# # Ridge

# %%
ri = Ridge(alpha=10)
ri.fit(x_train,y_train)
ri.score(x_test,y_test)*100
# Out:
# 70.1172798619439

# %%
print(mean_squared_error(y_test,ri.predict(x_test)))
print(mean_absolute_error(y_test,ri.predict(x_test)))
print(np.sqrt(mean_squared_error(y_test,ri.predict(x_test))))
# Out:
# 45175713837.6308
# 127473.87817154288
# 212545.79233104287

# %%
plt.figure(figsize=(10,10))
plt.bar(x.columns,ri.coef_)
plt.title('Ridge Regression')
plt.xlabel('columns')
plt.ylabel('coef')
plt.show()

# %%
df2 = pd.DataFrame({'col_name':x.columns,"LinearRegression":lr.coef_,"LassoRegression":la.coef_,"RidgeRegression":ri.coef_})

# %%
df2
# Out:
#          col_name  LinearRegression  LassoRegression  RidgeRegression
# 0        bedrooms     -31933.323647    -31933.312129    -31866.318398
# 1       bathrooms      34321.164242     34321.097861     34301.847479
# 2     sqft_living      80795.073362    257493.565227     80745.743844
# 3        sqft_lot       3680.017707      3679.979818      3680.927207
# 4          floors       3781.524687      3781.522634      3800.300712
# 5      waterfront      48657.277095     48657.269485     48635.746605
# 6            view      41105.171777     41105.172353     41105.481680
# 7       condition      15960.216811     15960.205416     15977.436778
# 8           grade     111158.084778    111158.110816    111034.344354
# 9      sqft_above      75409.776432    -83906.261601     75353.684160
# 10  sqft_basement      26570.283072    -58576.513723     26572.866269
# 11       yr_built     -78741.504396    -78741.486059    -78624.611536
# ...
